# %% [markdown]
# # Hyperparameter Testing on Each Model (Q6)

# %% [markdown]
# This notebook is used to show the 3 models, with one hyperparameter changed each time to be used to compare to the original model to see if any of the hyperparameters tested significantly effect the model

# %%
# Imports
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import tensorflow as tf

# local imports
from metrics import *
from visualization import *
from data_operations import load_data
# Out:
# 2024-11-06 15:34:52.848748: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-06 15:34:52.878555: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-06 15:34:52.878590: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-06 15:34:52.878616: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-06 15:34:52.885127: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-11-06 15:34:52.885945: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-06 15:34:53.707067: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Model 1  - Single Layer ANN

# %% [markdown]
# Used to visualize changes for hyperparameters. Compare with Model 1 Original

# %% [markdown]
# Hyperparameters changed: 64 -> 128 neurons in dense layer

# %%
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

model_name = "Single Layer ANN"
# Single layer ANN
model = Sequential([
    Flatten(input_shape=(28, 28)),    # 
    Dense(128, activation='relu'),    # changed from 64 ->128 neurons
    Dense(10)                         # 
])

model.compile(optimizer=Adam(learning_rate=0.01),  # Adam optimizer with 0.01 lr
              loss=SparseCategoricalCrossentropy(from_logits=True), # Use sparse categorical for multiclass
              metrics=['accuracy'])                                

# training and setting epochs
epochs = 10
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# evaluate  model
test_acc, preds = evaluate_model(model, ts_images, ts_labels)

# show training time and accuracy results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5338 - accuracy: 0.8096 - val_loss: 0.5147 - val_accuracy: 0.8159
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4400 - accuracy: 0.8430 - val_loss: 0.4221 - val_accuracy: 0.8489
# Epoch 3/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4121 - accuracy: 0.8516 - val_loss: 0.4317 - val_accuracy: 0.8517
# Epoch 4/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4009 - accuracy: 0.8562 - val_loss: 0.4252 - val_accuracy: 0.8546
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3964 - accuracy: 0.8575 - val_loss: 0.4166 - val_accuracy: 0.8550
# Epoch 6/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3791 - accuracy: 0.8620 - val_loss: 0.4151 - val_accuracy: 0.8635
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3730 - accuracy: 0.8640 - val_loss: 0.4379 - val_accuracy: 0.8467
# Epoch 8/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3740 - accuracy: 0.8652 - val_loss: 0.4993 - val_accuracy: 0.8336
# Epoch 9/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3672 - accuracy: 0.8677 - val_loss: 0.4375 - val_accuracy: 0.8464
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3588 - accuracy: 0.8685 - val_loss: 0.4684 - val_accuracy: 0.8409
# 313/313 [==============================] - 0s 1ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            80.96%              81.59%
#      2            84.30%              84.89%
#      3            85.16%              85.17%
#      4            85.62%              85.46%
#      5            85.75%              85.50%
#      6            86.20%              86.35%
#      7            86.40%              84.67%
#      8            86.52%              83.36%
#      9            86.77%              84.64%
#     10            86.85%              84.09%
#
# Total Training Time for all epochs: 60.62 seconds
# Total Training Accuracy (last epoch): 86.85%
# Total Validation Accuracy (last epoch): 84.09%

# %% [markdown]
# Changing only Adam -> SGD

# %%
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

model_name = "Single Layer ANN"
# Single layer ANN
model = Sequential([
    Flatten(input_shape=(28, 28)),    # 
    Dense(64, activation='relu'),    # keeping 64 neurons
    Dense(10)                         # 
])

model.compile(optimizer=SGD(learning_rate=0.01),  # change from Adam -> SGD
              loss=SparseCategoricalCrossentropy(from_logits=True), # Use sparse categorical for multiclass
              metrics=['accuracy'])                                

# training and setting epochs
epochs = 10
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# evaluate  model
test_acc, preds = evaluate_model(model, ts_images, ts_labels)

# show training time and accuracy results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.8288 - accuracy: 0.7359 - val_loss: 0.5845 - val_accuracy: 0.8035
# Epoch 2/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.5451 - accuracy: 0.8175 - val_loss: 0.5285 - val_accuracy: 0.8138
# Epoch 3/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4916 - accuracy: 0.8315 - val_loss: 0.4771 - val_accuracy: 0.8327
# Epoch 4/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4646 - accuracy: 0.8402 - val_loss: 0.4695 - val_accuracy: 0.8335
# Epoch 5/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4457 - accuracy: 0.8456 - val_loss: 0.4449 - val_accuracy: 0.8479
# Epoch 6/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4315 - accuracy: 0.8497 - val_loss: 0.4334 - val_accuracy: 0.8490
# Epoch 7/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4187 - accuracy: 0.8554 - val_loss: 0.4312 - val_accuracy: 0.8487
# Epoch 8/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4080 - accuracy: 0.8581 - val_loss: 0.4170 - val_accuracy: 0.8550
# Epoch 9/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3996 - accuracy: 0.8613 - val_loss: 0.4079 - val_accuracy: 0.8558
# Epoch 10/10
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3918 - accuracy: 0.8632 - val_loss: 0.4076 - val_accuracy: 0.8592
# 313/313 [==============================] - 0s 1ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            73.59%              80.35%
#      2            81.75%              81.38%
#      3            83.15%              83.27%
#      4            84.02%              83.35%
#      5            84.56%              84.79%
#      6            84.97%              84.90%
#      7            85.54%              84.87%
#      8            85.81%              85.50%
#      9            86.13%              85.58%
#     10            86.32%              85.92%
#
# Total Training Time for all epochs: 34.88 seconds
# Total Training Accuracy (last epoch): 86.32%
# Total Validation Accuracy (last epoch): 85.92%

# %% [markdown]
# Run for only 5 epochs compared to 10

# %%
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

model_name = "Single Layer ANN"
# Single layer ANN
model = Sequential([
    Flatten(input_shape=(28, 28)),    # flatten
    Dense(64, activation='relu'),    # 64 neurons
    Dense(10)                         # 10 outputs = 10 classes
])

model.compile(optimizer=Adam(learning_rate=0.01),  # Adam optimizer with 0.01 lr
              loss=SparseCategoricalCrossentropy(from_logits=True), # Use sparse categorical for multiclass
              metrics=['accuracy'])                                

# training and setting epochs
epochs = 25 # change from 10
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# evaluate  model
test_acc, preds = evaluate_model(model, ts_images, ts_labels)

# show training time and accuracy results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5338 - accuracy: 0.8093 - val_loss: 0.4322 - val_accuracy: 0.8487
# Epoch 2/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4338 - accuracy: 0.8448 - val_loss: 0.4513 - val_accuracy: 0.8424
# Epoch 3/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.4143 - accuracy: 0.8521 - val_loss: 0.4507 - val_accuracy: 0.8390
# Epoch 4/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4038 - accuracy: 0.8540 - val_loss: 0.4108 - val_accuracy: 0.8588
# Epoch 5/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3957 - accuracy: 0.8593 - val_loss: 0.4161 - val_accuracy: 0.8548
# Epoch 6/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3863 - accuracy: 0.8600 - val_loss: 0.4102 - val_accuracy: 0.8534
# Epoch 7/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3773 - accuracy: 0.8639 - val_loss: 0.4580 - val_accuracy: 0.8525
# Epoch 8/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3747 - accuracy: 0.8662 - val_loss: 0.4466 - val_accuracy: 0.8563
# Epoch 9/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3609 - accuracy: 0.8685 - val_loss: 0.4407 - val_accuracy: 0.8560
# Epoch 10/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3602 - accuracy: 0.8710 - val_loss: 0.4232 - val_accuracy: 0.8607
# Epoch 11/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3610 - accuracy: 0.8685 - val_loss: 0.4138 - val_accuracy: 0.8665
# Epoch 12/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3530 - accuracy: 0.8718 - val_loss: 0.4538 - val_accuracy: 0.8545
# Epoch 13/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3539 - accuracy: 0.8716 - val_loss: 0.4259 - val_accuracy: 0.8635
# Epoch 14/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3471 - accuracy: 0.8744 - val_loss: 0.4767 - val_accuracy: 0.8524
# Epoch 15/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3477 - accuracy: 0.8746 - val_loss: 0.4362 - val_accuracy: 0.8608
# Epoch 16/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3394 - accuracy: 0.8767 - val_loss: 0.4406 - val_accuracy: 0.8569
# Epoch 17/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3369 - accuracy: 0.8776 - val_loss: 0.4599 - val_accuracy: 0.8540
# Epoch 18/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3431 - accuracy: 0.8781 - val_loss: 0.4777 - val_accuracy: 0.8467
# Epoch 19/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3336 - accuracy: 0.8803 - val_loss: 0.4759 - val_accuracy: 0.8543
# Epoch 20/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3299 - accuracy: 0.8803 - val_loss: 0.4886 - val_accuracy: 0.8576
# Epoch 21/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3305 - accuracy: 0.8805 - val_loss: 0.4686 - val_accuracy: 0.8503
# Epoch 22/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3298 - accuracy: 0.8816 - val_loss: 0.4982 - val_accuracy: 0.8593
# Epoch 23/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3298 - accuracy: 0.8817 - val_loss: 0.5023 - val_accuracy: 0.8538
# Epoch 24/25
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3254 - accuracy: 0.8826 - val_loss: 0.5129 - val_accuracy: 0.8582
# Epoch 25/25
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3225 - accuracy: 0.8825 - val_loss: 0.4793 - val_accuracy: 0.8562
# 313/313 [==============================] - 0s 1ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            80.93%              84.87%
#      2            84.48%              84.24%
#      3            85.21%              83.90%
#      4            85.40%              85.88%
#      5            85.93%              85.48%
#      6            86.00%              85.34%
#      7            86.39%              85.25%
#      8            86.62%              85.63%
#      9            86.85%              85.60%
#     10            87.10%              86.07%
#     11            86.85%              86.65%
#     12            87.18%              85.45%
#     13            87.16%              86.35%
#     14            87.44%              85.24%
#     15            87.46%              86.08%
#     16            87.67%              85.69%
#     17            87.76%              85.40%
#     18            87.81%              84.67%
#     19            88.03%              85.43%
#     20            88.03%              85.76%
#     21            88.05%              85.03%
#     22            88.16%              85.93%
#     23            88.17%              85.38%
#     24            88.26%              85.82%
#     25            88.25%              85.62%
#
# Total Training Time for all epochs: 94.63 seconds
# Total Training Accuracy (last epoch): 88.25%
# Total Validation Accuracy (last epoch): 85.62%

# %% [markdown]
# # Model 2 - Double Layer ANN

# %% [markdown]
# Hyperparameters changed: 128 -> 256 neurons in dense layer

# %%
model_name = 'Double Layer ANN'
# Load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# Define a Double-Layer ANN model
model = Sequential([
    Flatten(input_shape=(28, 28)),      
    Dense(256, activation='relu'),      # Hidden layer - 256 neurons changed from 128 
    Dense(128, activation='relu'),       # Hideen layer - 128 neurons - changed from 64
    Dense(10)                            
])

model.compile(optimizer=Adam(learning_rate=0.01),  # Adam optimizer with 0.01 learning rate
              loss=SparseCategoricalCrossentropy(from_logits=True), # Use sparse categorical for multiclass
              metrics=['accuracy'])                                # Track accuracy 

# Train the model
epochs = 10
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# Evaluate the model
test_accuracy, preds = evaluate_model(model, ts_images, ts_labels)

# Display the results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 10s 6ms/step - loss: 0.5635 - accuracy: 0.7997 - val_loss: 0.4333 - val_accuracy: 0.8405
# Epoch 2/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4469 - accuracy: 0.8412 - val_loss: 0.4583 - val_accuracy: 0.8357
# Epoch 3/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4323 - accuracy: 0.8467 - val_loss: 0.4181 - val_accuracy: 0.8506
# Epoch 4/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.4021 - accuracy: 0.8585 - val_loss: 0.4325 - val_accuracy: 0.8492
# Epoch 5/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3937 - accuracy: 0.8630 - val_loss: 0.3972 - val_accuracy: 0.8609
# Epoch 6/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3866 - accuracy: 0.8633 - val_loss: 0.4076 - val_accuracy: 0.8589
# Epoch 7/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3834 - accuracy: 0.8657 - val_loss: 0.4165 - val_accuracy: 0.8595
# Epoch 8/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3727 - accuracy: 0.8689 - val_loss: 0.3924 - val_accuracy: 0.8678
# Epoch 9/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3701 - accuracy: 0.8703 - val_loss: 0.4145 - val_accuracy: 0.8578
# Epoch 10/10
# 1500/1500 [==============================] - 9s 6ms/step - loss: 0.3615 - accuracy: 0.8731 - val_loss: 0.4369 - val_accuracy: 0.8638
# 313/313 [==============================] - 1s 2ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            79.97%              84.05%
#      2            84.12%              83.57%
#      3            84.67%              85.06%
#      4            85.85%              84.92%
#      5            86.30%              86.09%
#      6            86.33%              85.89%
#      7            86.57%              85.95%
#      8            86.89%              86.78%
#      9            87.03%              85.78%
#     10            87.31%              86.38%
#
# Total Training Time for all epochs: 94.48 seconds
# Total Training Accuracy (last epoch): 87.31%
# Total Validation Accuracy (last epoch): 86.38%

# %% [markdown]
# Adam -> SGD optimizer

# %%
model_name = 'Double Layer ANN'
# Load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# Define a Double-Layer ANN model
model = Sequential([
    Flatten(input_shape=(28, 28)),     
    Dense(128, activation='relu'),      
    Dense(64, activation='relu'),       
    Dense(10)                            
])

model.compile(optimizer=SGD(learning_rate=0.01),  # changed to SGD
              loss=SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])                               

# Train the model
epochs = 10
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# Evaluate the model
test_accuracy, preds = evaluate_model(model, ts_images, ts_labels)

# Display the results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.8076 - accuracy: 0.7364 - val_loss: 0.5764 - val_accuracy: 0.8006
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.5274 - accuracy: 0.8176 - val_loss: 0.4887 - val_accuracy: 0.8324
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4701 - accuracy: 0.8366 - val_loss: 0.4524 - val_accuracy: 0.8431
# Epoch 4/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4381 - accuracy: 0.8461 - val_loss: 0.4470 - val_accuracy: 0.8393
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.4154 - accuracy: 0.8545 - val_loss: 0.4152 - val_accuracy: 0.8551
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3995 - accuracy: 0.8594 - val_loss: 0.4051 - val_accuracy: 0.8572
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3855 - accuracy: 0.8642 - val_loss: 0.3902 - val_accuracy: 0.8627
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3738 - accuracy: 0.8678 - val_loss: 0.3837 - val_accuracy: 0.8648
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3644 - accuracy: 0.8704 - val_loss: 0.3929 - val_accuracy: 0.8622
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3538 - accuracy: 0.8745 - val_loss: 0.3769 - val_accuracy: 0.8682
# 313/313 [==============================] - 1s 1ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            73.64%              80.06%
#      2            81.76%              83.24%
#      3            83.66%              84.31%
#      4            84.61%              83.93%
#      5            85.45%              85.51%
#      6            85.94%              85.72%
#      7            86.42%              86.27%
#      8            86.78%              86.48%
#      9            87.04%              86.22%
#     10            87.45%              86.82%
#
# Total Training Time for all epochs: 44.86 seconds
# Total Training Accuracy (last epoch): 87.45%
# Total Validation Accuracy (last epoch): 86.82%

# %% [markdown]
# 10-> 20 epochs

# %%
model_name = 'Double Layer ANN'
# Load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# Define a Double-Layer ANN model
model = Sequential([
    Flatten(input_shape=(28, 28)),     
    Dense(128, activation='relu'),      
    Dense(64, activation='relu'),       
    Dense(10)                            
])

model.compile(optimizer=Adam(learning_rate=0.01),  
              loss=SparseCategoricalCrossentropy(from_logits=True), 
              metrics=['accuracy'])                               

# Train the model
epochs = 20 # changed to 20
history, total_tr_time = train_model(model, tr_images, tr_labels, epochs=epochs, batch_size=32)

# Evaluate the model
test_accuracy, preds = evaluate_model(model, ts_images, ts_labels)

# Display the results
show_results(history, total_tr_time, epochs)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.5465 - accuracy: 0.8063 - val_loss: 0.4571 - val_accuracy: 0.8322
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4524 - accuracy: 0.8403 - val_loss: 0.4790 - val_accuracy: 0.8285
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4206 - accuracy: 0.8489 - val_loss: 0.4754 - val_accuracy: 0.8290
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.4106 - accuracy: 0.8517 - val_loss: 0.4486 - val_accuracy: 0.8403
# Epoch 5/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3975 - accuracy: 0.8579 - val_loss: 0.4475 - val_accuracy: 0.8478
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3889 - accuracy: 0.8623 - val_loss: 0.4363 - val_accuracy: 0.8457
# Epoch 7/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3798 - accuracy: 0.8636 - val_loss: 0.4637 - val_accuracy: 0.8453
# Epoch 8/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3790 - accuracy: 0.8655 - val_loss: 0.4508 - val_accuracy: 0.8495
# Epoch 9/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3830 - accuracy: 0.8656 - val_loss: 0.4761 - val_accuracy: 0.8524
# Epoch 10/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3690 - accuracy: 0.8684 - val_loss: 0.4166 - val_accuracy: 0.8603
# Epoch 11/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3665 - accuracy: 0.8711 - val_loss: 0.4902 - val_accuracy: 0.8407
# Epoch 12/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3600 - accuracy: 0.8730 - val_loss: 0.4513 - val_accuracy: 0.8502
# Epoch 13/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3624 - accuracy: 0.8711 - val_loss: 0.4417 - val_accuracy: 0.8609
# Epoch 14/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3625 - accuracy: 0.8714 - val_loss: 0.4323 - val_accuracy: 0.8597
# Epoch 15/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3537 - accuracy: 0.8747 - val_loss: 0.4279 - val_accuracy: 0.8551
# Epoch 16/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3521 - accuracy: 0.8743 - val_loss: 0.4154 - val_accuracy: 0.8598
# Epoch 17/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3397 - accuracy: 0.8775 - val_loss: 0.4339 - val_accuracy: 0.8589
# Epoch 18/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3563 - accuracy: 0.8733 - val_loss: 0.4320 - val_accuracy: 0.8668
# Epoch 19/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3444 - accuracy: 0.8790 - val_loss: 0.4674 - val_accuracy: 0.8478
# Epoch 20/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3493 - accuracy: 0.8771 - val_loss: 0.4203 - val_accuracy: 0.8600
# 313/313 [==============================] - 0s 1ms/step
# Training and Evaluation Results
#  Epoch Training Accuracy Validation Accuracy
#      1            80.63%              83.22%
#      2            84.03%              82.85%
#      3            84.89%              82.90%
#      4            85.17%              84.03%
#      5            85.79%              84.78%
#      6            86.23%              84.57%
#      7            86.36%              84.53%
#      8            86.55%              84.95%
#      9            86.56%              85.24%
#     10            86.84%              86.03%
#     11            87.11%              84.07%
#     12            87.30%              85.02%
#     13            87.11%              86.09%
#     14            87.14%              85.97%
#     15            87.47%              85.51%
#     16            87.43%              85.98%
#     17            87.75%              85.89%
#     18            87.33%              86.68%
#     19            87.90%              84.78%
#     20            87.71%              86.00%
#
# Total Training Time for all epochs: 128.68 seconds
# Total Training Accuracy (last epoch): 87.71%
# Total Validation Accuracy (last epoch): 86.00%

# %% [markdown]
# # Model 3 - KNN

# %% [markdown]
# changed k-neighbours to 1 from 5

# %%
model_name = "KNN"
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# flatten images so knn can use
tr_images_flat = tr_images.reshape(-1, 28 * 28)  # Flatten to 784 features
ts_images_flat = ts_images.reshape(-1, 28 * 28)

# Define Model
k_neighbors = 1  # Number of neighbors for k-NN
knn_model = KNeighborsClassifier(n_neighbors=k_neighbors)

# stratified k-Fold is better with multiclass to even the class distribution
n_splits = 5 # fold numebr
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=21)
cv_scores = []  

# loop to iterate though each fold
time_start = time.time()
for train_index, val_index in skf.split(tr_images_flat, tr_labels):
    # Split the data for training and validation sets for each fold
    X_train, X_val = tr_images_flat[train_index], tr_images_flat[val_index]
    y_train, y_val = tr_labels[train_index], tr_labels[val_index]
    
    # Train the knn model on the training set 
    knn_model.fit(X_train, y_train)
    
    # evaluate model (val set)
    val_predictions = knn_model.predict(X_val)
    fold_accuracy = accuracy_score(y_val, val_predictions)
    cv_scores.append(fold_accuracy)

time_end = time.time()
print(f"Time to run {n_splits} folds: {time_end - time_start:.2f} seconds")

# print cross-val accuracy results
print(f"Stratified Cross-Validation Accuracy (5-fold): {sum(cv_scores) / len(cv_scores) * 100:.2f}%")

test_preds = knn_model.predict(ts_images_flat)

# Calculate metrics for the test set
test_accuracy = accuracy_score(ts_labels, test_preds)

# Print the test set accuracy
print("\nTest Set Accuracy:")
print(f"Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Time to run 5 folds: 109.56 seconds
# Stratified Cross-Validation Accuracy (5-fold): 84.93%
#
# Test Set Accuracy:
# Accuracy: 84.27%

# %% [markdown]
# Change metric from euclidian -> chebyshev

# %% [markdown]
# Note I wanted to use manhattan or cosine just for comparison - but due to the nature of the data the computation was taking way to long and i would not be able to speed it up without effecting other metrics so for the sake of this investigation only chebyshev and euclidan were tested

# %%
model_name = "KNN"
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# flatten images so knn can use
tr_images_flat = tr_images.reshape(-1, 28 * 28)  # Flatten to 784 features
ts_images_flat = ts_images.reshape(-1, 28 * 28)

# Define Model
k_neighbors = 5  # Number of neighbors for k-NN
knn_model = KNeighborsClassifier(n_neighbors=k_neighbors, metric='chebyshev') #changed from euclidian to chebyshev 

# stratified k-Fold is better with multiclass to even the class distribution
n_splits = 5 # fold number
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=21)
cv_scores = []  

# loop to iterate though each fold
time_start = time.time()
for train_index, val_index in skf.split(tr_images_flat, tr_labels):
    # Split the data for training and validation sets for each fold
    X_train, X_val = tr_images_flat[train_index], tr_images_flat[val_index]
    y_train, y_val = tr_labels[train_index], tr_labels[val_index]
    
    # Train the knn model on the training set 
    knn_model.fit(X_train, y_train) 
    
    # evaluate model (val set)
    val_predictions = knn_model.predict(X_val)
    fold_accuracy = accuracy_score(y_val, val_predictions)
    cv_scores.append(fold_accuracy)

time_end = time.time()
print(f"Time to run {n_splits} folds: {time_end - time_start:.2f} seconds")

# print cross-val accuracy results
print(f"Stratified Cross-Validation Accuracy (5-fold): {sum(cv_scores) / len(cv_scores) * 100:.2f}%")

test_preds = knn_model.predict(ts_images_flat)

# Calculate metrics for the test set
test_accuracy = accuracy_score(ts_labels, test_preds)

# Print the test set accuracy
print("\nTest Set Accuracy:")
print(f"Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Time to run 5 folds: 1062.51 seconds
# Stratified Cross-Validation Accuracy (5-fold): 63.79%
#
# Test Set Accuracy:
# Accuracy: 62.92%

# %% [markdown]
# change weights from default "uniform" to distance

# %%
model_name = "KNN"
# load the data
tr_images, tr_labels, ts_images, ts_labels = load_data()

# flatten images so knn can use
tr_images_flat = tr_images.reshape(-1, 28 * 28)  # Flatten to 784 features
ts_images_flat = ts_images.reshape(-1, 28 * 28)

# Define Model
k_neighbors = 5  # Number of neighbors for k-knn_model = KNeighborsClassifier(n_neighbors=k_neighbors, weights='distance')  #changed from uniform to weighted

# stratified k-Fold is better with multiclass to even the class distribution
n_splits = 5 # fold number
skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=21)
cv_scores = []  

# loop to iterate though each fold
time_start = time.time()c
for train_index, val_index in skf.split(tr_images_flat, tr_labels):
    # Split the data for training and validation sets for each fold
    X_train, X_val = tr_images_flat[train_index], tr_images_flat[val_index]
    y_train, y_val = tr_labels[train_index], tr_labels[val_index]
    
    # Train the knn model on the training set 
    knn_model.fit(X_train, y_train) 
    
    # evaluate model (val set)
    val_predictions = knn_model.predict(X_val)
    fold_accuracy = accuracy_score(y_val, val_predictions)
    cv_scores.append(fold_accuracy)

time_end = time.time()
print(f"Time to run {n_splits} folds: {time_end - time_start:.2f} seconds")

# print cross-val accuracy results
print(f"Stratified Cross-Validation Accuracy (5-fold): {sum(cv_scores) / len(cv_scores) * 100:.2f}%")

test_preds = knn_model.predict(ts_images_flat)

# Calculate metrics for the test set
test_accuracy = accuracy_score(ts_labels, test_preds)

# Print the test set accuracy
print("\nTest Set Accuracy:")
print(f"Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Time to run 5 folds: 108.42 seconds
# Stratified Cross-Validation Accuracy (5-fold): 85.56%
#
# Test Set Accuracy:
# Accuracy: 85.15%

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9b078dc4-e2c3-414e-bc4d-86356ec945c2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
